# %% [markdown]
# <a href="https://colab.research.google.com/github/LC1332/Zero-Haruhi/blob/main/notebook/try_read_subtitle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/CardBuild/exp1230
# Out:
# subtitle_50.zip

# %% [markdown]
# 请为我实现一段python代码，将/content/drive/MyDrive/CardBuild/exp1230/subtitle_50.zip 拷贝到/content/下
#
# 并且将其中的内容解压缩到/content/input

# %%
import shutil
import zipfile
import os

# 源文件路径
source_zip = '/content/drive/MyDrive/CardBuild/exp1230/subtitle_50.zip'
# 目标路径
destination_dir = '/content/'
# 解压缩目标文件夹
unzip_dir = '/content/input/'

# 拷贝文件
destination_zip = os.path.join(destination_dir, os.path.basename(source_zip))
shutil.copy(source_zip, destination_zip)

# 确保解压缩目标文件夹存在
if not os.path.exists(unzip_dir):
    os.makedirs(unzip_dir)

# 解压缩文件
with zipfile.ZipFile(destination_zip, 'r') as zip_ref:
    zip_ref.extractall(unzip_dir)

print("文件已拷贝并解压缩到指定目录。")
# Out:
# 文件已拷贝并解压缩到指定目录。

# %% [markdown]
# 我希望实现一段Python代码
#
# 在/content/input下有很多电影的字幕文件
#
# 有.srt, .sub, .ass格式的字幕
#
# 我希望对他们进行批量读取
#
# 并且将字幕的内容（仅文字内容）
#
# 保存到/output下的同名的txt中
#
# 如果不能正常解析，则跳过
#
# 请用python的pysrt库为我实现

# %%
# !pip install -q pysrt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pysrt (setup.py) ... done

# %%
# !pip install -q chardet

# %%
# !rm -rf /content/output

# %%
# !mkdir /content/output

# %%
import pysrt
import os
import glob
import chardet

input_dir = '/content/input'
output_dir = '/output'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        raw_data = f.read()
    return chardet.detect(raw_data)['encoding']

# 遍历所有.srt文件

count = 0
for srt_file in glob.glob(os.path.join(input_dir, '*.srt')):
    try:
        # 检测文件编码
        encoding = detect_encoding(srt_file)
        if not encoding:
            # print(f"Cannot detect encoding for {srt_file}")
            encoding = 'utf-8'
            # continue

        # 加载字幕文件
        try:
            subs = pysrt.open(srt_file, encoding=encoding)
        except Exception as e:
            print(f"Error loading {srt_file}: {e}")
            continue

        # 提取文本内容
        text_content = '\n'.join([sub.text_without_tags for sub in subs])

        count += 1

        save_name = srt_file.replace("/input/", "/output/") + ".txt"
        # continue

        # 构建输出文件路径
        # base_name = os.path.basename(srt_file)
        # output_file_path = os.path.join(output_dir, os.path.splitext(base_name)[0] + '.txt')

        # 写入文本文件
        with open(save_name, 'w', encoding='utf-8') as f:
            f.write(text_content)

        print("done ", save_name)

    except Exception as e:
        print(f"Error processing {srt_file}: {e}")
        continue

print("Processing completed.")
# Out:
# done  /content/output/╞╒┬▐├╫╨▐╦╣.srt.txt
# done  /content/output/Yogi.Bear.DVDRip.XviD-ARROW.srt.txt
# done  /content/output/Let.Me.In.2010.DVDRIP.XViD.T0XiC.iNK.srt.txt
# done  /content/output/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk2.English.srt.txt
# Error loading /content/input/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk1.ChineseT.srt: 'charmap' codec can't decode byte 0x90 in position 0: character maps to <undefined>
# Error loading /content/input/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk2.ChineseT.srt: 'charmap' codec can't decode byte 0x90 in position 0: character maps to <undefined>
# done  /content/output/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk1.English.srt.txt
# done  /content/output/╘ñ▓·╞┌.Due.Date.BDRip.XviD-ARROW.[sharethefiles.com].chn.srt.txt
# done  /content/output/contraband.2012.limited.dvdrip.xvid-amiable.cd1.englsih.srt.txt
# done  /content/output/[├═╣φ╔·╚╒╤τ].My.Soul.to.Take.2010.DVDRip.XviD-AMiABLE.chn.srt.txt
# done  /content/output/my.soul.to.take.2010.dvdrip.xvid-amiable.eng.srt.txt
# Error loading /content/input/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk3.ChineseT.srt: 'charmap' codec can't decode byte 0x90 in position 0: character maps to <undefined>
# done  /content/output/sparks-sleepwalk-xvid.srt.txt
# done  /content/output/jane.eyre.2011.dvdrip.xvid-amiable.cd1.chs&en.srt.txt
# done  /content/output/The Crow.1994.720p.BluRay.x264-SiNNERS.srt.txt
# done  /content/output/The Dilemma (2011).720p.En.Felony.srt.txt
# Error loading /content/input/no.strings.attached.2011.bdrip.xvid-amiable.[wnet.co.il].chs.srt: 'gb2312' codec can't decode byte 0xef in position 30: illegal multibyte sequence
# done  /content/output/Tremors.1990.m-HD.x264-AsCo.srt.txt
# done  /content/output/dash-tcontvotdt-repacka.srt.txt
# done  /content/output/dash-tcontvotdt-repackb.srt.txt
# done  /content/output/A Fish Called Wanda.srt.txt
# done  /content/output/[╟α┤║╬Φ╗ß╗╩║≤].Confessions.Of.A.Teenage.Drama.Queen.2004.DVDRiP.XviD-DEiTY.chs.srt.txt
# done  /content/output/The Green Hornet (2011).Defaced1.En.srt.txt
# Error loading /content/input/Paul.2011.DVDRiP.XViD-ALLiANCE.chs.srt: 'gb2312' codec can't decode byte 0x85 in position 0: illegal multibyte sequence
# done  /content/output/[├└░µ╔·╚╦╬≡╜°].Let.Me.In.2010.DVDRIP.READNFO.XViD-T0XiC-iNK.chn.srt.txt
# Error loading /content/input/[╗ε┬±].Buried.2010.BDRiP.XviD-iMBT.chs.srt: 'gb2312' codec can't decode byte 0x8c in position 10: illegal multibyte sequence
# Error loading /content/input/[┼«│¼╚╦].Supergirl.-.The.Movie,.Director&#39;S.Cut.[1984].chs.srt: 'gb2312' codec can't decode byte 0x81 in position 2: illegal multibyte sequence
# done  /content/output/╬╥╬¬╟«┐±].Mad.Money.2008.DVD-RMVB-╚╦╚╦╙░╩╙-softice_.rmvb.srt.txt
# done  /content/output/[╥╣░δ╣φ╟├├┼2].House.2.The.Second.Story.1987.GoDSMaCK.DVDRip.chs.srt.txt
# done  /content/output/The.Adjustment.Bureau.2011.V2.TS.XViD.-.IMAGiNE.en.srt.txt
# Error loading /content/input/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk1.ChineseS.srt: 'gb2312' codec can't decode byte 0xa1 in position 2: illegal multibyte sequence
# done  /content/output/Red.Riding.Hood.2011.R5.XviD-BiDA.cht.srt.txt
# done  /content/output/arrow-season.of.the.witch.srt.txt
# Error loading /content/input/no.strings.attached.2011.bdrip.xvid-amiable.[wnet.co.il].cht.srt: 'gb2312' codec can't decode byte 0x9e in position 15: illegal multibyte sequence
# done  /content/output/[░▌╝√╘└╕╕┤≤╚╦3].Little.Fockers.2010.DVDRip.XviD-DEFACED.chs.srt.txt
# done  /content/output/Repo.Man.1984.iNT.DVDRip.XviD-iLS.eng.srt.txt
# done  /content/output/[╒Γ╕÷╔▒╩╓╜½╙╨─╤].Grosse.Pointe.Blank.1997.DVDRiP.XviD.chs.srt.txt
# done  /content/output/From Prada To Nada (2011).720p.En.srt.txt
# done  /content/output/f-true.grit.720p.srt.txt
# done  /content/output/Country.Strong.2010.Bluray.720p.DTS.x264-CHD.srt.txt
# done  /content/output/contraband.2012.limited.dvdrip.xvid-amiable.cd2.englsih.srt.txt
# done  /content/output/Take.Me.Home.Tonight.2011.BRRip.XviD.AC3-SANTi.srt.txt
# done  /content/output/[╥╣░δ╣φ╟├├┼].House.1986.iNTERNAL.DVDRip.DivX-GoDSMaCK.chs.srt.txt
# done  /content/output/jane.eyre.2011.dvdrip.xvid-amiable.cd1.chs.srt.txt
# done  /content/output/[╔±├╪╡─╞Ñ╚°].Mystic.Pizza.1988.DVDRip.DivX.chs.srt.txt
# done  /content/output/the.future.2011.dvdrip.xvid-amiable.srt.txt
# done  /content/output/I.Spit.On.Your.Grave.UNRATED.2010.DVDRip.XviD-TWiZTED-cd1.cn..srt.txt
# done  /content/output/╬ú╟Θ╚²╚╒.The.Next.Three.Days.XviD.chn.srt.txt
# done  /content/output/[╥╣░δ╣φ╟├├┼.III].House.3.The.Horror.Show.1989.DVDRip.GoDSMaCK.chs.srt.txt
# Error loading /content/input/[┴╓┐╧┬╔╩ª].The.Lincoln.Lawyer.2011.R5.LiNE.XViD-FiRMA.chs.srt: 'gb2312' codec can't decode byte 0x86 in position 12: illegal multibyte sequence
# done  /content/output/A.Late.Quartet.2012.LIMITED.DVDRip.XviD-PSYCHD.srt.txt
# done  /content/output/jane.eyre.2011.dvdrip.xvid-amiable.cd2.chs&en.srt.txt
# done  /content/output/The Green Hornet (2011).Defaced2.En.srt.txt
# Error loading /content/input/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk2.ChineseS.srt: 'gb2312' codec can't decode byte 0xa1 in position 2: illegal multibyte sequence
# done  /content/output/jane.eyre.2011.dvdrip.xvid-amiable.cd2.chs.srt.txt
# done  /content/output/The Wildest Dream.720p.en.srt.txt
# done  /content/output/The Hours.srt.txt
# done  /content/output/Trouble.with.the.Curve.2012.BRRip.XviD.AbSurdiTy.srt.txt
# done  /content/output/Grosse.Pointe.Blank.(1997).DVDRip.DivX3LM.chs.srt.txt
# done  /content/output/[▒¿╨┼╡─╚╦].Repo.Man.1984.iNT.DVDRip.XviD-iLS.chs.srt.txt
# done  /content/output/rabbit.hole.2010.dvdrip.xvid-amiable.srt.txt
# done  /content/output/Braveheart.1995.720p.BluRay.x264-SiNNERS.srt.txt
# Error loading /content/input/Hanna.2011.R5.LiNE.XViD-MC8.[sharethefiles.com].chs.srt: 'gb2312' codec can't decode byte 0x81 in position 6: illegal multibyte sequence
# Error loading /content/input/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk3.ChineseS.srt: 'gb2312' codec can't decode byte 0xa1 in position 2: illegal multibyte sequence
# Error loading /content/input/[─π╘⌡╓¬╡└].How.Do.You.Know.BDRip.XviD-DASH.CD2.chn.srt: 'gb2312' codec can't decode byte 0xa8 in position 0: illegal multibyte sequence
# done  /content/output/Tamara.Drewe.2010.DVDRiP.XViD-LARCENY.CD1.cn.srt.txt
# done  /content/output/Blue.Valentine.LIMITED.RERIP.720p.Bluray-CBGB.srt.txt
# done  /content/output/The.Adjustment.Bureau.2011.TS.XViD.Feel-Free.Needs.chs.srt.txt
# done  /content/output/Shaolin (2011).720p.En.Hdchina.srt.txt
# Error loading /content/input/dmd-tle.srt: 'gb2312' codec can't decode byte 0x9b in position 24: illegal multibyte sequence
# done  /content/output/Red.Riding.Hood.2011.R5.XviD-BiDA.chs.srt.txt
# done  /content/output/The Roommate (2011).En.720p.srt.txt
# done  /content/output/The.Rock.1996.BDrip.1080p.x264.DTS.ThreeAudio-CHD.Disk3.English.srt.txt
# Error loading /content/input/The.Tempest.2011.DVDRiP.XviD.AbSurdiTy.chs.srt: 'gb2312' codec can't decode byte 0x81 in position 4: illegal multibyte sequence
# Error loading /content/input/exvid-rangext-cd2.srt: 'gb2312' codec can't decode byte 0xc7 in position 0: illegal multibyte sequence
# done  /content/output/somewhere.2010.proper.dvdrip.xvid-unveil.srt.txt
# done  /content/output/jane.eyre.2011.dvdrip.xvid-amiable.cd1.en.srt.txt
# done  /content/output/Paul.2011.DVDRiP.XViD-ALLiANCE.cht.srt.txt
# done  /content/output/Mystic Pizza(Xvid)(Darkside_RG).en.srt.txt
# done  /content/output/Maverick.1994.720p.BluRay.X264-AMIABLE.srt.txt
# done  /content/output/I.Spit.On.Your.Grave.UNRATED.2010.DVDRip.XviD-TWiZTED-cd2.cn.srt.txt
# done  /content/output/l-tamara.cd2.English.srt.txt
# done  /content/output/Alive.[1993].DVDRip.XviD.chs.srt.txt
# Error loading /content/input/[╔±├╪╡─╞Ñ╚°].Mystic.Pizza.1988.DVDRip.DivX.cht.srt: 'gb2312' codec can't decode byte 0x82 in position 2: illegal multibyte sequence
# Error loading /content/input/[╔ó╡»┬╢┬╢].Something.Wild.1986.XviD.AC3.CD2-WAF.chs.srt: 'gb2312' codec can't decode byte 0x85 in position 0: illegal multibyte sequence
# done  /content/output/l-tamara.cd1.English.srt.txt
# done  /content/output/Buried.2010.BDRiP.XviD-iMBT.eng.srt.txt
# done  /content/output/unstop.chs.srt.txt
# done  /content/output/Tamara.Drewe.2010.DVDRiP.XViD-LARCENY.CD2.cn.srt.txt
# done  /content/output/Hope.Springs.2012.BDRip.XviD-SPARKS.srt.txt
# Error loading /content/input/exvid-rangext-cd1.srt: 'gb2312' codec can't decode byte 0xc7 in position 0: illegal multibyte sequence
# done  /content/output/Alive.[1993].DVDRip.XviD.cht.srt.txt
# done  /content/output/Hanna.2011.R5.LiNE.XViD-MC8.[sharethefiles.com].cht.srt.txt
# done  /content/output/The Mechanic (2011).DVDRip.XviD.AC3.chn.srt.txt
# done  /content/output/The.Rover.2014.720p.BluRay.H264.AAC-RARBG.srt.txt
# Error loading /content/input/[╔ó╡»┬╢┬╢].Something.Wild.1986.XviD.AC3.CD1-WAF.chs.srt: 'gb2312' codec can't decode byte 0x85 in position 4: illegal multibyte sequence
# Error loading /content/input/[─π╘⌡╓¬╡└].How.Do.You.Know.BDRip.XviD-DASH.CD1.chn.srt: 'gb2312' codec can't decode byte 0x86 in position 24: illegal multibyte sequence
# done  /content/output/Tigerland (2000) 720p BluRay x264-Japhson.srt.txt
# done  /content/output/jane.eyre.2011.dvdrip.xvid-amiable.cd2.en.srt.txt
# done  /content/output/d-i.spit.on.your.grave.720.srt.txt
# done  /content/output/The Mechanic (2011).DVDRip.XviD.AC3.eng.srt.txt
# done  /content/output/Paranormal.Activity.2.2010.UNRATED.DVDRip.XviD-Larceny.chn.srt.txt
# done  /content/output/English.srt.txt
# Processing completed.

# %%
print(srt_file)
# Out:
# /content/input/English.srt

# %%
data = {}

data["movie_name"] = "例子电影"

data["major_character"] = "查理"

data["selected_five_dialogues"] = [
    [
      {"text": "你知道吗，萨姆，我今天早上在买咖啡时碰到了一个占卜师。", "said_by": "查理"},
      {"text": "哦，真的吗？她告诉你什么好消息？", "said_by": "萨姆"},
      {"text": "她说我会遇到一些‘大变化’。所以我换了个口味，从拿铁改成了美式。", "said_by": "查理"},
      {"text": "查理，那不是占卜师说的变化吧！", "said_by": "萨姆"},
      {"text": "嘿，生活就是要有点小刺激，对吧？即使是咖啡口味的改变也算是冒险。", "said_by": "查理"},
      {"text": "你的幽默感永远都是你的‘大变化’。", "said_by": "萨姆"}
    ],
    [
      {"text": "你是什么人？", "said_by": "汤姆"},
      {"text": "我是查理呀，怎么士别三日都不认识我啦？", "said_by": "查理"}
    ]
]


data["personality"] = "根据input的内容，以及你所了解到的这部movie的知识，总结角色的性格，在这个例子中，查理是一个幽默乐观的人"

data["appearance"] = "根据input的内容，以及你所了解到的这部movie的知识，总结角色的外貌特征"

data["world_view_setting"] = "根据input的内容，以及你所了解到的这部movie的知识，总结角色所处的世界观, 以及角色的关键经历"

data["character_description"] = "查理是一个幽默、乐观、随和且善于用轻松的方式处理日常生活的人。"

data["language_style"] = "根据input的内容，以及你所了解到的这部movie的知识，总结角色的语言风格"


data["greeting_information"] = "嗨我的老伙计{user_name}，你还记得我吗，是我呀查理。"


data["other_characters"] = ["汤姆","萨姆"]

import json

# 将字典转换为JSON字符串，缩进为4个空格
json_str_with_spaces = json.dumps(data, indent=4, ensure_ascii = False)

print(json_str_with_spaces)
# Out:
# {
#     "movie_name": "例子电影",
#     "major_character": "查理",
#     "selected_five_dialogues": [
#         [
#             {
#                 "text": "你知道吗，萨姆，我今天早上在买咖啡时碰到了一个占卜师。",
#                 "said_by": "查理"
#             },
#             {
#                 "text": "哦，真的吗？她告诉你什么好消息？",
#                 "said_by": "萨姆"
#             },
#             {
#                 "text": "她说我会遇到一些‘大变化’。所以我换了个口味，从拿铁改成了美式。",
#                 "said_by": "查理"
#             },
#             {
#                 "text": "查理，那不是占卜师说的变化吧！",
#                 "said_by": "萨姆"
#             },
#             {
#                 "text": "嘿，生活就是要有点小刺激，对吧？即使是咖啡口味的改变也算是冒险。",
#                 "said_by": "查理"
#             },
#             {
#                 "text": "你的幽默感永远都是你的‘大变化’。",
#                 "said_by": "萨姆"
#             }
#         ],
#         [
#             {
#                 "text": "你是什么人？",
#                 "said_by": "汤姆"
#             },
#             {
#                 "text": "我是查理呀，怎么士别三日都不认识我啦？",
#                 "said_by": "查理"
#             }
#         ]
#     ],
#     "personality": "根据input的内容，以及你所了解到的这部movie的知识，总结角色的性格，在这个例子中，查理是一个幽默乐观的人",
#     "appearance": "根据input的内容，以及你所了解到的这部movie的知识，总结角色的外貌特征",
#     "world_view_setting": "根据input的内容，以及你所了解到的这部movie的知识，总结角色所处的世界观, 以及角色的关键经历",
#     "character_description": "查理是一个幽默、乐观、随和且善于用轻松的方式处理日常生活的人。",
#     "language_style": "根据input的内容，以及你所了解到的这部movie的知识，总结角色的语言风格",
#     "greeting_information": "嗨我的老伙计{user_name}，你还记得我吗，是我呀查理。",
#     "other_characters": [
#         "汤姆",
#         "萨姆"
#     ]
# }

# %%
print(data)
# Out:
# {'movie_name': '例子电影', 'major_character': '查理', 'selected_five_dialogues': [[{'text': '你知道吗，萨姆，我今天早上在买咖啡时碰到了一个占卜师。', 'said_by': '查理'}, {'text': '哦，真的吗？她告诉你什么好消息？', 'said_by': '萨姆'}, {'text': '她说我会遇到一些‘大变化’。所以我换了个口味，从拿铁改成了美式。', 'said_by': '查理'}, {'text': '查理，那不是占卜师说的变化吧！', 'said_by': '萨姆'}, {'text': '嘿，生活就是要有点小刺激，对吧？即使是咖啡口味的改变也算是冒险。', 'said_by': '查理'}, {'text': '你的幽默感永远都是你的‘大变化’。', 'said_by': '萨姆'}], [{'text': '你是什么人？', 'said_by': '汤姆'}, {'text': '我是查理呀，怎么士别三日都不认识我啦？', 'said_by': '查理'}]], 'personality': '根据input的内容，以及你所了解到的这部movie的知识，总结角色的性格，在这个例子中，查理是一个幽默乐观的人', 'appearance': '根据input的内容，以及你所了解到的这部movie的知识，总结角色的外貌特征', 'world_view_setting': '根据input的内容，以及你所了解到的这部movie的知识，总结角色所处的世界观, 以及角色的关键经历', 'character_description': '查理是一个幽默、乐观、随和且善于用轻松的方式处理日常生活的人。', 'language_style': '根据input的内容，以及你所了解到的这部movie的知识，总结角色的语言风格', 'greeting_information': '嗨我的老伙计{user_name}，你还记得我吗，是我呀查理。', 'other_characters': ['汤姆', '萨姆']}

# %% [markdown]
# 测试新的openai的对接

# %%
# !pip install -q openai

# %%
from openai import OpenAI

import os
import openai
key = "sk-WafsA4" # add you key here
key_bytes = key.encode()
os.environ["OPENAI_API_KEY"] = key_bytes.decode('utf-8')

client = OpenAI(
    api_key = os.environ["OPENAI_API_KEY"]
)

# %%
task_prompt = """请帮我从电影的对白中，总结出现频率最高的某个角色的信息，参考Example Output中的json格式进行输出

json中包括这些字段:

- movie_name: 电影名称
- major_character: 出现频率最高的角色名称
- selected_five_dialogues: 该角色相关的5段对白，同时根据上下文，判断每一句话的说话人，保存在said_by字段中
- personality: 角色的性格
- appearance: 角色的外貌特征
- character_description: 角色的简要描述
- world_view_setting: 角色所处的世界观, 以及角色的关键经历
- language_style: 角色的语言风格
- greeting_information: 假设major_character遇见角色{{user_name}}时的开场白，如果对话中出现遇到的这个角色，其名字用"{{user_name}}"代替，如果无法提供，则输出空字符串
- other_characters: 除了major_character之外，电影中其他主要角色的名字

请参考Example中给出的Input-Output例子，对新的Input进行分析，提取出主角的信息"""

# %%
example_input = """File Name:
例子电影对白输入.srt

srt:
你知道吗，萨姆，我今天早上在买咖啡时碰到了一个占卜师。
哦，真的吗？她告诉你什么好消息？
她说我会遇到一些“大变化”。所以我换了个口味，从拿铁改成了美式。
查理，那不是占卜师说的变化吧！
嘿，生活就是要有点小刺激，对吧？即使是咖啡口味的改变也算是冒险。
你的幽默感永远都是你的“大变化”。
你是什么人？
我是查理呀，怎么士别三日都不认识我啦？"""

# %%
example_output = json_str_with_spaces

# %%
#@title 指定输入

input = """File Name:
让子弹飞.srt

srt:
你一个师爷敢冒充县长？
那就要看你的本事了
师爷，当夫妻最要紧的是什么？
恩爱！
听不见，再说一遍
恩爱！
来，见过母亲大人
母亲大人好，小六子有礼了！
你出生入死，还带着儿子啊？
他爹是我的兄弟，阵亡了
所以他就成了我的儿子
所以呢，你现在就是我的母亲大人！
等这桩买卖做完后
“天之涯”
“地之角”
“知交半零落”
“一壶浊酒尽余欢”
“夕阳山外山”
好，好好
汤师爷
是好吃，还是好听？
也好听，也好吃
都好，都好！
我马某走南闯北
靠的就是能文能武，与众不同
不光吃喝玩乐，更要雪月风花
马县长此番风度
正好比
大风起兮云飞扬
屁！
刘邦是个小人！
力拔山兮气盖世
屁！ 屁，屁
汤师爷
你要是拍我马屁
就先要先过夫人这一关
写首诗，写首诗！
要有风，要有肉
要有火锅，要有雾
要有美女，要有驴！
起来，起来，起来
一起吃！一起唱！
报告县长！我们铁血十八星陆军
护送县长安全上任！
我们…
不吃饭！
没打中？
让子弹飞一会儿
老二老三跟我走
其他人把白马抓回来！
火锅？
爹，全都找遍了
没钱，没货，也没有银子
人倒是剩两活的，杀不杀？
钱藏在哪儿了？说出来
闹钟响之前要是说不出来
脑袋搬家
哭？
哭也算时间啊
有什么就说什么嘛
这位夫人，你是谁？
我就是县长夫人啊
失敬！失敬！
那你就是县太爷？
有钱！有钱…！
我跟县长进城上任
县长淹死了，现在没有
    {"role":"assistant","content":example_output},
    {"role":"user","content":input}
]

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-1106",
  messages=messages,
  response_format={ "type": "json_object" },
  temperature=0
)

print(completion.choices[0].message.content)
# Out:
# {
#     "movie_name": "让子弹飞",
#     "major_character": "黄四郎",
#     "selected_five_dialogues": [
#         [
#             {
#                 "text": "你一个师爷敢冒充县长？",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "那就要看你的本事了",
#                 "said_by": "黄四郎"
#             }
#         ],
#         [
#             {
#                 "text": "六爷，黄四郎这招叫杀人不用刀",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "我给你爹出的招叫杀人诛心",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "不能拼命啊！拼命还怎么赚钱！",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "六子，爹发誓一定给你报仇！",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "把脸收拾收拾",
#                 "said_by": "汤师爷"
#             }
#         ],
#         [
#             {
#                 "text": "我是做什么生意的？明白吗？",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "不明白",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "小半个民国的烟土都是黄老爷您在贩卖",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "错！不过是给刘都统当跑腿的",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "而且只是其中一条腿",
#                 "said_by": "黄四郎"
#             }
#         ],
#         [
#             {
#                 "text": "我今天讨的就是一个公平",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "对",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "问谁讨？问县长儿子。为什么？",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "他吃了两碗粉，只给了一碗的钱",
#                 "said_by": "汤师爷"
#             },
#             {
#                 "text": "这就叫作不公平！",
#                 "said_by": "汤师爷"
#             }
#         ],
#         [
#             {
#                 "text": "我脑子里想的只有一件事",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "替黄老爷把这条腿接上！",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "一个张麻子也太嚣张了！",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "欺负到黄哥头上了，不答应",
#                 "said_by": "黄四郎"
#             },
#             {
#                 "text": "喝酒",
#                 "said_by": "黄四郎"
#             }
#         ]
#     ],
#     "personality": "黄四郎是一个强势、狡猾、善于权谋的角色，善于利用权力和资源来达到自己的目的。",
#     "appearance": "根据电影中的描述，黄四郎是一个外表威严、气质高贵的人物。",
#     "world_view_setting": "黄四郎是一个在南国有着重要影响力的人物，掌握着贩卖烟土等生意，同时也涉及政治权力的斗争。",
#     "character_description": "黄四郎是一个强势、狡猾、善于权谋的人物，外表威严、气质高贵，掌握着南国重要的生意和政治权力。",
#     "language_style": "黄四郎的语言风格显得自信、傲慢，善于运用言辞来表达自己的意图。",
#     "greeting_information": "",
#     "other_characters": [
#         "汤师爷"
#     ]
# }
