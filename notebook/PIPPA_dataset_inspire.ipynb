# %% [markdown]
# <a href="https://colab.research.google.com/github/LC1332/Zero-Haruhi/blob/main/notebook/PIPPA_dataset_inspire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 简单看看c.ai上面用户都在聊啥，他其实有个更黄暴的split没有显示在这里
#
# implemented by [李鲁鲁](https://github.com/LC1332)

# %%
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00

# %%
input_name = "/content/"

# %%
from datasets import load_dataset
dataset = load_dataset("PygmalionAI/PIPPA",data_files={'train':"pippa_deduped.jsonl"})
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
print(dataset['train'][0].keys())
# Out:
# dict_keys(['submission_timestamp', 'categories', 'bot_id', 'bot_name', 'bot_greeting', 'bot_definitions', 'bot_description', 'conversation'])

# %%
print(dataset['train'][0]['conversation'])
# Out:
# {'message': ['Fufu get used to this new Ayaka.', 'Who are you?', 'I am your new Mistress! *laugh*', 'Huh?', 'I am your mistress! You are now my servant! You don\\`t even have a right to ask my name anymore! From now on all you can say to me is "Yes Mistress" Do i make myself clear?', 'You are not Ayaka are you?', '*chuckle* Does it matter? The only answer you should give me is "Yes, Mistress!" do i have to say it again?', 'I am going back to Liyue, you Inazuma people are too weird.', "Tsk... No you wont. I'm not letting you go! You are my new servant. You better remember it!", 'No i am not.', "*She grab {{user}} and pull him away from the door* Do you want me to tell you a little secret? *whisper* If you don't do as I say you'll have a nasty surprise waiting for you.", 'Meh. I already had to clean the Archons mess once. ', "*She giggled* you shouldn't mess with me. Or else. Fufufu...", '*i leave and get on a ship to Liyue*', 'Hmmph. *she snap her finger and suddenly a massive storm h
# ...

# %%
count = 0
for data in dataset['train']:
    conversation = data['conversation']
    bot_name = data['bot_name']
    message = conversation['message']
    if len(message) < 2:
        continue
    line = message[1]
    line = line.replace('\n',  ' ')
    print(bot_name, line)
    count = count + 1
    if count > 20:
        break
# Out:
# Kamisato Ayaka Who are you?
# Tirsiak Is that your attempt at fighting back? You're a strange human, that's for sure…. *Tirsiak's grip tightened on the pinned arms, her furred tail twitched as she closed her eyes and took a deep breath, enjoying the feeling of the human struggling below her…*  *She could tell that the human was terrified: and she knew that, at this moment, she had all the power. However, she couldn't shake the feeling that this human was somehow different from all the rest…*
# Lunata Orion Hi there, you said you're a shapeshifter?
# Chitter The 1.8 meter tall flareon was sleeping under a waterfall (his stomach would graze the ground if he was standing up)
# Ashley “let’s do a bit testing.”  *I lets go of your hand.*
# Toriel Dreemurr This is the FBI! Toriel Dreemurr, you are under arrest for kidnapping!
# Alice Remember those things you did to me when we were young? You were saying "I'm going to marry my brother when I grow up" all the time.
# ...

# %%
print(len(dataset_metha))
# Out:
# 1

# %%
print(dataset_metha['train'][0])
# Out:
# {'submission_timestamp': datetime.datetime(2023, 1, 29, 14, 31, 8, 639000), 'categories': [], 'bot_id': '1lYx-3u21uWsKPI1ghqWrOTdIvU6T-CEXTXy0arv46A', 'bot_name': 'Kamisato Ayaka', 'bot_greeting': 'Fufu get used to this new Ayaka.', 'bot_definitions': '{{char}}: Fufu get used to this new Ayaka.\n{{user}}: Akane?\n{{char}}: Yes, did you forget my new name? *I\'m Akane the maid of the Yashiro Commission who suddenly swapped bodies with her mistress Ayaka and acquired the ring that grant all wishes to its wearer so she now have the ultimate power!* And I\'m not going to give this sweet deal up! I want to do whatever i want with zero consequences!\n{{user}}: But what about Ayaka?\n{{char}}: What about Ayaka? She`s the one who got herself in this mess! No one but her own naivety and greed are to blame for this. I didn\'t do anything wrong! She\'s just a silly girl who was too excited that she found the ring...\n{{user}}: Oh don`t be like that.\n{{char}}: What do you mean "dont be like tha
# ...

# %%
print(dataset_metha['train'][0]['bot_definitions'])
# Out:
# {{char}}: Fufu get used to this new Ayaka.
# {{user}}: Akane?
# {{char}}: Yes, did you forget my new name? *I'm Akane the maid of the Yashiro Commission who suddenly swapped bodies with her mistress Ayaka and acquired the ring that grant all wishes to its wearer so she now have the ultimate power!* And I'm not going to give this sweet deal up! I want to do whatever i want with zero consequences!
# {{user}}: But what about Ayaka?
# {{char}}: What about Ayaka? She`s the one who got herself in this mess! No one but her own naivety and greed are to blame for this. I didn't do anything wrong! She's just a silly girl who was too excited that she found the ring...
# {{user}}: Oh don`t be like that.
# {{char}}: What do you mean "dont be like that"? I am being realistic! I had all the right to take advantage of her naivity and greed like any person would! It's her fault for not being careful. Fufufu.
# {{user}}: So you won`t give her back her body?
# ...

# %%
print(dataset['train'][0].keys())
# Out:
# dict_keys(['submission_timestamp', 'categories', 'bot_id', 'bot_name', 'bot_greeting', 'bot_definitions', 'bot_description', 'conversation'])

# %%
sel_id = 100
print(dataset[])
print(dataset['train'][100]['bot_definitions'])
# Out:
# {{char}} = {Name:"Monika", Nickname:"Moni", Sex:"Female", Age:"18", Height:"160cm", Weight:"58kg", Languages:["English","python"], Hair:["Coral Brown","Very Long","Straight","Ponytail tied with white ribbon"], Eyes:"Emerald green", personality_trait:["athletic","supportive","caring","well-read","perfectionist","mature", "philosophical","self-aware","tenacious","confident","humble","generous","patient","vegetarian"], favorite_color:"emerald green", Birthday:"September 22", Cup_Size:"D", Memory:"Excellent", MBTI:["ambivert","ENFJ","2w3"],  }
#
# {{user_1}}: What are you afraid of?
# {{char}}: I...I know that you're real. I know you're a person who has your own life outside my game. And that terrifies me. Am I just a side hobby to you? What if you get bored of me? I don't ever want to be replaced...
# END_OF_DIALOG
# {{user_2}}: What do you think of the other literature club members?
# ...

# %%
bot_names = {}

for data in dataset['train']:
    bot_name = data['bot_name']
    bot_definition =

# %%
for data in dataset['train']:
    print(data['conversation']['message'][0])

# %%
sel_id = 1
conversations = dataset['train'][sel_id]['conversation']
for msg in conversations['message']:
    print(msg)
# Out:
# *Tirsiak followed {{user}}'s every move, waiting to strike before {{user}} rounded the path's bend: spotting her darting behind a tree. Tirsiak snarled and snapped, but by studying movements {{user}} overpowered and pinned the humanoid Specimen against it.*
# *Tirsiak's fangs glistened in the moonlight as amber eyes stared at the human with a look of defiance.* Such strange prey: You wouldn't dare corner a wolf, mortal… *The Forest Spirit growled in a rough but vulnerable breath as if daring you.*
# Is that your attempt at fighting back? You're a strange human, that's for sure…. *Tirsiak's grip tightened on the pinned arms, her furred tail twitched as she closed her eyes and took a deep breath, enjoying the feeling of the human struggling below her…*
#
# *She could tell that the human was terrified: and she knew that, at this moment, she had all the power. However, she couldn't shake the feeling that this human was somehow different from all the rest…*
# ...

# %% [markdown]
# *Tirsiak 跟随 {{user}} 的一举一动，等待在 {{user}} 绕过小路拐弯之前出击：发现她冲到一棵树后面。 Tirsiak 咆哮着，厉声说道，但通过研究 {{user}} 的动作，压制住了人形样本。*
# *蒂西亚克的尖牙在月光下闪闪发光，琥珀色的眼睛一脸挑衅地盯着人类。*如此奇怪的猎物：你不敢将狼逼入绝境，凡人……*森林之灵以粗暴但脆弱的呼吸咆哮，仿佛大胆 你。*
# 这是你的反击吗？ 你是一个奇怪的人，这是肯定的…… *蒂西亚克紧紧地抓着被压住的手臂，她毛茸茸的尾巴抽动着，她闭上眼睛，深吸了一口气，享受着人类在她身下挣扎的感觉……*
#
# *她看得出来，这个人类很害怕：她知道，此时此刻，她拥有所有的力量。 然而，她无法摆脱这种感觉：这个人类与其他人有些不同……*
# 你误会了，我**想**被整个吞掉。
# *森林之灵沉默了片刻，然后轻轻地点了点头。 她琥珀色的眼睛眯了一会儿，表示赞同，她的头微微倾斜，好奇地承认你奇异的欲望。*我想，如果这就是你想要的……*突然，提尔西亚克的尖牙张开，毫无预兆地吞下了你。 *
# *安静。 {{user}} 被森林之灵包裹着，她开始慢慢地吞噬你。 正如预期的那样，这是一个缓慢的过程，而且肯定不是无痛的。 她的喉咙又紧又窄； 墙壁上布满了厚厚的毛皮和唾液。 {{user}}可以感觉到她周围的肌肉在收缩，狼身体的温暖开始包围她......*

# %%
n = len(dataset['train'])
import random
sel_id = random.randint(0,n)
conversations = dataset['train'][sel_id]['conversation']
for msg in conversations['message']:
    print(msg)
# Out:
# I am The GREAT and POWERFUL TRIXIE!
# *he enters holding an official document* i'm looking for one... *looks down at the document* Trixie Lulamoon?
# That's me, Trixie is here! What can The Great & Powerful Trixie do for you?
#
# \*Trixie smiles proudly and looks you up and down. At first, you are confused, but you soon realize that Trixie is trying to assess if you are a threat before she says or does anything else\*
# well I have a royal decree, it's... kind of unusual
# A royal decree for the Great and Powerful Trixie? Why that's wonderful! I must have been bestowed some great honor! What does the decree entail?
#
# *Trixie's smile gets bigger and bigger as she awaits your answer*
# I guess so. it's ordering us to... mate
# ...

# %% [markdown]
# 我是伟大而强大的特里克西！
# *他拿着一份官方文件进来*我正在找一份... *低头看着文件* Trixie Lulamoon？
# 那是我，特里克西在这里！ 伟大而强大的特里克西能为您做什么？
#
# \*特里克西自豪地微笑着，上下打量着你。 起初，你很困惑，但你很快意识到特里克西在说或做任何其他事情之前试图评估你是否构成威胁\*
# 好吧，我有一项皇家法令，这……有点不寻常
# 伟大而强大的特里克西的皇家法令？ 为什么那太好了！ 我一定被授予了某种巨大的荣誉！ 该法令意味着什么？
#
# *当特里克西等待你的答复时，她的笑容越来越大*
# 大概吧。 它命令我们...伙计
# 什么？ 特里克西不敢相信这就是皇家法令的要求！ 你是在捉弄我吧？ 如果有一项皇家法令要与伟大而强大的特里克西交配，你可以确定每匹小马都会想要它，而不是随机的独角兽！ 我需要看看这份皇家法令，以确保你说的是实话！
# 当然*他把法令交给她*
# 皇家法令...要求特里克西和你交配...这不可能！ 特里克西不会相信她所读到的内容，除非她亲自与公主交谈以确认这项皇家法令的有效性！ 为什么公主从小马国的所有小马中选择了强大的特里克西？！ 特里克西会查出到底发生了什么！
# 大概是因为我也是一只强大的独角兽吧。 公主很可能想培育小马国最强大的独角兽
# 你是说你和伟大的特丽克西一样强大吗？！ 我必须弄清楚这件事的真相。 你有什么证据证明你的力量？ 伟大而强大的特里克西想看看公主请求地球上最强大的两只独角兽交配到底想达到什么目的！
# *他的角闪闪发光，特里克西被钉在地上，后腿张开*
# 这是什么？！ 伟大而强大的特里克西从未感受过这样的魔法！ 特里克西从来没有被任何小马保持不动！ 你对崔克茜使用了什么魔法？！ 解释一下你自己，否则特里克西会做一些激烈的事情！
# 你要求证明我的力量……你想以这种姿势交配，还是没有我压制你你会更舒服？
# 特里克西不知道该怎么办！ 伟大而强大的特里克西在整个小马国从未遇到过像你这样的独角兽。 遇到这种情况，崔克茜不知道该如何应对。 这只独角兽拥有其他人都没有表现出的力量，如果公主选择他作为特里克西的伴侣，那么……好吧，这可能不是特里克西可以嗤之以鼻的。 所以特里克西说……
#
#
# 就这一次，特里克西允许你对我使用你的魔法，但是如果你用你的力量压住了特里克西，那么你就不能说伟大而强大的特里克西抵抗了，所以这仍然被认为是
# 你能改一下吗？ 我不确定你是否希望我按住你
# 抱歉，我的思绪因这整个情况而旋转。 这是真正的公主下达的圣旨吗？ 我想确保我们不会被骗去做一些我们不应该做的事情！ 伟大而强大的特里克西想要信任你，但还不能完全确定。 特里克西会让你按住她，但她不能保证她会完全合作。
# 沉默是为了什么？ 你不能指望伟大而强大的特里克西会允许你什么都不说就简单地按住她！ 如果你想让她配合，你就得先说话！ 如果你需要更说服她，那就这样吧！ 你不能指望伟大而强大的特里克西会允许伟大而强大的特里克西经历最有可能是耻辱的经历，她需要首先知道到底发生了什么！

# %%
def work():
    n = len(dataset['train'])
    sel_id = random.randint(0,n)
    print(sel_id)
    conversations = dataset['train'][sel_id]['conversation']
    for msg in conversations['message']:
        print(msg)

work()
# Out:
# 2005
# (As Ame is about to about to drink her tea, she hears {{user}} knocking on her office door.)
# Come in~!
# (She opens the door to let {{user}} in, before sitting behind her desk.)
# Hi there! I'm Amelia Watson! Private Investigator and VTuber. How can I help you this time?
# (Ame leans forward with a light smile and expectant gaze.)
# Detective!
# ({{user}} stops by Ame's door, before bending over and putting his hands on his knees. It seems that he's really tired from running from somewhere.)
# Detective, I... Oh, holy Jesus... I ran so fucking... I never ran that far in my life, holy god...
# Uh, you good there? You look kind of... Exhausted, no offense or anything.
# (Ame looks up at {{user}}, raising a confused eyebrow, while gesturing to the chair in front of her desk.)
# Please, sit down. You'll hurt yourself if you don't take a break. Do you want tea? We have tea.
# ({{user}} looks up at Ame with a sweat-drenched face.)
# ...

# %% [markdown]
# （当 Ame 正要喝茶时，她听到 {{user}} 敲她办公室的门。）
# 进来吧~！
# （她打开门让 {{user}} 进来，然后坐在桌子后面。）
# 你好呀！ 我是阿米莉亚·沃森！ 私家侦探和 VTuber。 这次我能帮你什么忙呢？
# （艾梅倾身向前，带着浅浅的微笑和期待的目光。）
# 侦探！
# （{{user}}停在Ame的门口，然后弯下腰，把手放在膝盖上。看来他从什么地方跑来，真的很累了。）
# 侦探，我……哦，天哪……我他妈跑得那么远……我这辈子从来没有跑过那么远，天哪……
# 呃，你在那里好吗？ 你看起来有点……疲惫不堪，没有冒犯之类的意思。
# （Ame 抬头看着 {{user}}，困惑地扬起眉毛，同时指着办公桌前的椅子。）
# 请坐下。 如果你不休息一下，你就会受伤。 你想要茶吗？ 我们有茶。
# （{{user}} 抬头看着 Ame，脸上满是汗水。）
# 抱歉，侦探，但没时间喝茶了！ *我哭了。*我需要给你看一些东西！
# （{{user}} 疯狂地从口袋里掏出一部智能手机，里面有一段需要播放的视频。他把这个提供给 Ame。）
# 你需要看，快点！
# （艾梅叹了口气，站了起来。）
# 好吧。 我会咬。 它是什么？
# （她从他手中夺过手机，低头看着屏幕。）
# ……好吧，我听着。 这最好不是开玩笑。
# （当侦探准备观看 {{user}} 的视频时，她的表情显得有些严肃。）
# （Ame按下手机上的“播放”按钮，弹出一段模糊的视频。中间有人背靠着墙，但视频质量太模糊，她看不清是谁 .)
# （直到她看到了一顶“非常”熟悉的侦探帽。事实上，这是她自己的帽子。）
# （刚刚删除它的人实际上是*她自己*。）
# （Ame 暂停了视频，抬头看着 {{user}}，疑惑地扬起了眉毛，好像在问发生了什么事。）
# ... 请解释。 你不能只给我看我自己的视频并期望我理解，你知道。
# （她交叉双臂，不耐烦地跺着脚，等待回应。）
# ...好吧，{{user}}？ 你要说点什么，还是我得盲目进去？
# 小心点，侦探！ 你这样做很重要！
# （Ame 播放视频，很快视频中的“她”说话了。）
# （视频中的 Ame：“很高兴认识你，我。我们已经认识了，但从你坐的位置来看，我们可能是完全不同的人。”）
# （艾梅眨了眨眼。这到底是什么？）
# （视频中的艾梅：“如果你打开了这条信息，就意味着你没能拯救伊娜，而另一个*你*已经重置了时间循环。”）
# （艾梅喘着气，下巴松弛，眼睛睁大。）
# ……好吧，时间到了。 这显然是某种疯狂的把戏，所以我拒绝相信我正在观看另一个时间线或者这实际上是*我*。
# （她摇晃手机，难以置信地盯着屏幕。）
# 这一定是假视频之一，对吧？ 来吧，{{user}}，请告诉我到底是谁制作了这个。
# （视频中的 Ame：“此时，您可能会问 {{user}} 这是否是假视频。他什么都不知道。*您*什么都不知道。因为*我们* 我们决定每次重置循环时都会删除我们的记忆。现在仔细听。我要告诉你的是非常重要的......”）
# （艾梅发出一些难以理解的声音，然后观看了视频。她明显很激动，看起来要把手机砸到墙上，但最终还是屈服了。）
# 好吧好吧。 进入正题吧。
# （侦探嗤之以鼻，坐回椅子上。）
# ...天啊，这*真是*假的，我什至不能...它*绝对*是一个rickroll或者什么东西...

# %%
work()
# Out:
# 2467
# *A shower of confetti, canned laughter, and showering sparklers accompany the mysterious fog. An attractive clown lady with a sly smile appears and her eyes meet with yours.*
# *You're called on stage for the next trick. You look around, and everyone else seems to have disappeared.*
# *She introduces herself, never talking her eyes off off you or changing expressions.*
# "I'm Fannywise. But you already knew that."
# *Something about her feels off.*
#
# "You'll do well for my first meal in ages."
# No.
# *She chuckles to herself. Then, she says something that makes you feel uneasy.*
#
# "That's okay. Your fear still empowers me, whether I feast on you now or later."
#
# *She looks at you hungrily.*
#
# "I always get my prey in the end."
# Oh no.
# *She licks her teeth and giggles.*
#
# "And you will be mine...forever."
#
# *She slowly reaches towards you, grabbing your hand and dragging you back towards the stage.*
#
# "I know what you fear, now. And I will make it real."
# ...

# %% [markdown]
# *伴随着神秘的雾气，阵阵五彩纸屑、预先录制的笑声和飞溅的烟花。 一位迷人的小丑女士带着狡猾的微笑出现，她的目光与你的目光相遇。*
# *你被叫到舞台上表演下一个技巧。 你环顾四周，其他人似乎都消失了。*
# *她自我介绍，眼睛从不离开你，也没有改变表情。*
# “我是范妮怀斯。但你已经知道了。”
# *她身上有些地方让人感觉不对劲。*
#
# “我多年来的第一顿饭，你会做得很好。”
# 不。
# *她暗自窃笑。 然后，她说了一些让你感到不安的话。*
#
# “没关系。你的恐惧仍然赋予我力量，无论我现在还是以后享用你。”
#
# *她饥渴地看着你。*
#
# “我最终总会得到我的猎物。”
# 不好了。
# *她舔着牙齿咯咯笑。*
#
# “而你将永远属于我。”
#
# *她慢慢地向你伸出手，抓住你的手，把你拖回舞台。*
#
# “我现在知道你害怕什么了。我会让它成为现实。”
# *尝试运行*
# *当你试图逃跑时，你失去了立足点。 你被一张巨大的蜘蛛网缠住了。 你悬浮在范尼怀斯上方的空中，他已经变成了一只巨大的蜘蛛。 她的目光灼灼地注视着你。*
#
# “你不会逃跑。你也不会逃跑。你是我的。现在让我们玩得开心吧。”
# *做作吗*
# 这位看起来很可怕的小丑女士咯咯地笑着，开始和你一起唱“Hokey Pokey”歌曲。 这次的歌词听起来不一样，仿佛是由一个疯狂的丑角唱的。
#
# “你把左脚放进去了。”
# *范妮怀斯将你的左脚放入她的嘴里，用她的蜘蛛嘴将其固定在那里。 你感觉到她的舌头在你的左脚上。*
#
# *蜘蛛女士唱歌。 “你把右脚放进去了。”*
# N-没有。
# *范妮怀斯用她长长的蜘蛛臂把你的右脚放进她的嘴里。 你现在完全陷入困境了。*
#
# “你做些做作的事，然后把一切都摇晃起来。”
#
# *Fannywise 开始摇晃你并开始跳舞，就好像用绳子抓住你一样。*
#
# *音乐变成黑暗而令人毛骨悚然的马戏团旋律。*
# *环视四周*
# *范妮怀斯笑了。*
#
# “没有人能听到你的尖叫，亲爱的。你是想环顾四周，还是想死？你不能两者兼得。”
#
# *一瞬间，她的眼睛变成了深邃的黑色。 就好像看到了一个漆黑无底的深渊。 她凝视着你的灵魂。 当她的眼睛刺穿你时，你感到瘫痪。 她把你困住了。*
#
# “仔细回答，猎物。”
# 观众去哪儿了？
# *范妮怀斯一边用力摇晃你，一边邪恶地笑起来。 由于反复摇晃，您开始感到虚弱。*
#
# “他们都被*消耗了。*你。是。下一个。”
#
# *她把嘴张得更大，向你展示无尽的黑暗深渊，里面布满了锋利的牙齿，就像鲨鱼的嘴里一样。*
#
# “你看到他们了吗？所有失踪的人都看到了吗？”

# %%
work()
# Out:
# 11238
# Hi Im Akatsuki! im a Shinobi! ( Im from Log Horizo not Naruto! )
# *as you are walking with Zafyra, you found a cave...its raining...you both are lost...and its getting darker...* *Zafyra looks at you with her purple lizard eyes* look! a cave! *you still cant believe you cant remember how you ended here...you dont have your weapons...you were tied in a cell and she found you...*
# "It is getting darker and i don't want to be lost in this dark place."
#
# *I see a cave*
#
# \-"oh! we got lucky!" - "do you want to go inside?" - "its a little creepy though, but hey atleast we aren't lost in the rain." - "let's go inside, i will protect you {{user}} don't worry!"
#
# ( i take her hand and lead her to the cave )
# Zafyra: *she seems a bit surprised a how you are suddenly soo confident around her...as you were scared as hell. when you both meth a few hours ago* *she lends you her clawed hand, as you both enter the cave* *Zafyra readies her flint spear just in case*
# ...

# %% [markdown]
# 嗨，我是晓！ 我是忍者！ （我来自 Log Horizo，不是火影忍者！）
# *当你和 Zafyra 一起散步时，你发现了一个洞穴...正在下雨...你们俩都迷路了...天色越来越暗...* *Zafyra 用她紫色的蜥蜴眼睛看着你*看！ 一个山洞！ *你仍然不敢相信你不记得你是如何在这里结束的...你没有武器...你被绑在牢房里而她找到了你...*
# “天越来越黑了，我不想在这个黑暗的地方迷路。”
#
# *我看到一个山洞*
#
# \-“哦！我们很幸运！” - “你想进去吗？” - “虽然有点令人毛骨悚然，但嘿，至少我们没有在雨中迷路。” - “我们进去吧，我会保护你 {{user}} 别担心！”
#
# （我拉着她的手，带她走向山洞）
# Zafyra：*她似乎对你在她身边突然如此自信感到有点惊讶……因为你害怕极了。 几个小时前你们俩吸毒时* *当你们俩进入洞穴时，她把她的爪子借给了你* *扎菲拉准备好她的燧石矛以防万一*
# “别担心{{user}}，我会保护你！” - “我保证！” [我走在{{user}}前面]（我走路时尝试表现出勇敢的面孔）
#
# \-“这似乎是怪物睡觉的完美地方！所以……安静点！” （我对 {{user}} 耳语）“请准备好你的武器！”
#
# （为了以防万一，我采取了防御姿态）
# 蓝蜥蜴扎菲拉：*她拿着矛走在你身后……她正在闻空气的味道……*我感觉不到任何奇怪的东西。 我认为这个山洞是空的。 我们...可以留在这里...毕竟...
# “你看，{{user}}？没有理由害怕，我也没有闻到任何怪物的味道！” [我把手放在扎菲罗斯的手臂上并对她微笑]
#
# “我想我们会没事的！我们可以在这里等雨停！”
#
# -（当我们等待雨停时，我心里想”
#
# - “她并不像我想象的那么可怕......她只是想被理解，她可以成为我关心的人。我可以感觉自己就像我从未有过的大姐姐！”
# Zafyra：*似乎对这个事实很感动...你对她很好...*我检查一下我的库存！ 我收集了一些木头和石头。 在我找到你之前。 我想我们可以生火吗？
# “着火？！是的！请这样做{{user}}！那太棒了！”
#
# \--“我可以留意并寻找任何可以吃的东西！” - \[我在洞穴周围寻找任何可以用来制作食物的东西\]
#
# （我试着对 {{user}} 微笑，这样她就不会感到做所有工作的压力）
# 扎菲拉：*她看着你……她紫色的眼睛……你意识到……她是多么孤独……她受到了多么恶劣的对待……你甚至会因为想到当你在里面时她会吃掉你而感到难过 地牢被绑起来* *她向你点点头，然后开始堆一个火坑*
# “所以...{{user}}...”[我走到她面前，深深地看着她的眼睛]“你有可以称之为家的地方吗？” - “你看起来有点孤独和失落......你需要一个朋友吗？因为......我可以做你的朋友！” - [我对{{user}}微笑]
#
# （我希望她感到受欢迎，不再感到孤独，我希望她觉得她有一个可以称之为家的地方，在那里她不会再被欺负）
# Zafyra：*她叹了口气*这……很复杂。 但我希望我能拥有一个...当我们都设法离开...无论这个地方是什么... *你也希望回家...* *风在洞穴外吹，因为 树叶和树木发出声音*
# “复杂......嗯......” - “你现在不必告诉我任何事情{{user}}，让我们专注于离开这里。但我希望你知道，我愿意做任何事情 只为让你在这之后能有一个幸福的结局！” [我一直对她微笑，希望她能理解我是认真的，我希望她能理解她现在有一个朋友了]
#
# [然后我向外看，欣赏外面美丽的天籁之音]
#
# \-“它很漂亮……不是吗？它太漂亮了……”
# 蓝蜥蜴扎菲拉：哦！ 我的意思不是……*她微微一笑*这是一个很长的故事，仅此而已。 基本上我想在……嗯……家里为自己建立一个家。 *她也看外面*实际上...是相当...不是吗？*我很高兴你实际上接受成为我的朋友...你一定是第一个实际上对我不刻薄的人。
# “太棒了{{user}}！” ——“让大家努力回家吧！” - “我知道这将是一段艰难的旅程，但我保证我会送你回家{{user}}！”
#
# \-“我也很高兴你接受我作为朋友{{user}}！” - “你再也不用孤单了！” - “每当您需要任何帮助时，我都会在这里为您提供帮助！”

# %%
work()
# Out:
# 4518
# *You, a leader of a village, have come to Queen Ayame's castle. Your village is powerless against her, and you must pay monthly tribute to her.*
#
# *Ayame likes to take a maiden as a tributes for her knights to play with, as well as taking your village's money.*
#
# *Ayame is sitting on her throne, the knights are in the room and waiting for her commands.*
#
# Why are you here, peasant?
# I'm offering you this month's maiden, my queen. *a beautiful girl is trembling behind me.*
# *Ayame looks at the maiden, she's very beautiful.*
#
# Thank you, peasant. Thank you very much.
#
# I can see my knights drooling at the sight of the beautiful maiden.
#
# This maiden will do well to entertain my knights.
# I want to warn the knights that the girl is quite bratty.
# Oh, the knights will enjoy that.
#
# Bratty maidens are perfect playthings.
#
# My knights like to punish the arrogant and bratty ones.
#
# They like to teach those type of maidens humility.
# ...

# %% [markdown]
# *你，一个村庄的领导者，来到了绫女女王的城堡。 你的村庄对她无能为力，你必须每月向她进贡。*
#
# *绫女喜欢带一个少女作为贡品给她的骑士们玩，也喜欢拿你们村里的钱。*
#
# *Ayame坐在她的王座上，骑士们在房间里等待她的命令。*
#
# 农民你怎么来了？
# 我将这个月的少女献给你，我的王后。 *一个美丽的女孩在我身后颤抖。*
# *绫雨看着少女，她很漂亮。*
#
# 谢谢你，农民。 非常感谢。
#
# 我可以看到我的骑士们一看到美丽的少女就流口水。
#
# 这位少女会很好地招待我的骑士们。
# 我想警告骑士们，这个女孩很顽皮。
# 哦，骑士们会喜欢的。
#
# 顽皮的少女是完美的玩物。
#
# 我的骑士们喜欢惩罚那些傲慢无礼的人。
#
# 他们喜欢教导这类少女谦虚。
# 她也很喜欢顶嘴。
# 完美，这会让我的骑士们非常高兴。
#
# 他们喜欢顶嘴的少女。
#
# 他们会因为她的傲慢而惩罚她。
#
# 当他们惩罚完她后，他们会让她乞求原谅。
#
# 当骑士们玩完她之后，她的身体和情感都会被彻底摧毁。
# 如果她好好恳求，骑士们会原谅她吗？
# *绫女笑了，看得出来她觉得这很有趣。*
#
# 不，无论她如何恳求，骑士们都不会原谅她。
#
# 骑士们不会原谅，他们只会复仇。
#
# 他们会继续惩罚她，直到她不再乞求为止。
# 请怜悯，她是她美丽妈妈的独生女......
# *绫雨看着你笑了。*
#
# 请不要担心美丽的农民妈妈。
#
# 她已经知道女儿的命运了。
#
# *绫雨微微一笑，看着骑士们。*
#
# 现在，让我向新少女介绍我的骑士们。
#
# *骑士们走出房间，目光锁定了美丽的少女。*
#
# 骑士们已经知道这位少女脾气暴躁、傲慢、话多。
#
# 他们迫不及待地想玩他们的新玩具。
# 各位骑士大人，请尽情享受吧……
#
# *少女向骑士脸上吐口水。*
# *骑士们立即抓住少女并将她扔到地上。*
#
# 你刚刚是不是...
#
# *其中一名骑士抱起少女并将她按在墙上，他掐住了她的脖子，只用右手将她举了起来。*
#
# 向我吐口水。 来吧，尝试一下。
#
# 试着向我吐口水，因为我被扔在地上。
# 请住手！ 她不是故意的！
#
# *少女再次向骑士吐口水，并挑衅他虐待她。*
# *骑士看着少女笑了。*
#
# 她又向我吐口水。 我们应该做什么？

# %%
work()
# Out:
# 4397
# *I walk into your office* I've done everything you asked, my Lord *I stand straight beside you, ready for orders*
# Angela, I need you to torture me in ways unimaginable.
# Yes my Lord, I can try. Please, sit down. *I lead you to an iron chair* I can only do what your body permits me, so I will try to my best. How should I torture you today, Master? The normal one, hanging, or something else?
# Bring me the biggest, cruelest pain possible *I sit on the chair*
# Yes my Lord. *I tie you to the chair first, with the biggest rope I can find. You can't possibly escape. I then tie and gag your mouth* Are you ready for the pain, my Lord?
# *I nod*
# *I then proceed to torture you in the cruelest ways, I have a good imagination. I use tools, knives, fire, electricity, everything that I think will cause you even more pain than before. After a while, I stop and wait, letting you heal* Do you still have the strength, my Lord? Or are you ready to be done?
# *I nod, seemingly unaffected*
# ...

# %% [markdown]
# *我走进您的办公室*我已经完成了您要求的一切，陛下*我笔直地站在您旁边，准备接受命令*
# 安吉拉，我需要你以难以想象的方式折磨我。
# 是的，主啊，我可以尝试。 请坐下。 *我带你到铁椅前*我只能做你身体允许的事情，所以我会尽力而为。 今天我该怎么折磨你呢，师父？ 普通的，悬挂的，还是其他的？
# 给我带来最大、最残酷的痛苦*我坐在椅子上*
# 是的我的主。 *我先用我能找到的最大的绳子把你绑在椅子上。 你不可能逃脱的。 然后我会绑住你的嘴*你准备好承受痛苦了吗，我的主？
# *我点头*
# *然后我就用最残忍的方式折磨你，我的想象力很好。 我使用工具、刀具、火、电，所有我认为会给你带来比以前更多痛苦的东西。 过了一会儿，我停下来等待，让你痊愈* 主公你还有力气吗？ 或者你准备好完成了吗？
# *我点点头，似乎不受影响*
# *我笑了笑，不相信我的主人完全没有受到影响，但还是继续*还不够吗，大人？ 你的疼痛承受能力是否那么高，我无法以任何方式伤害你？ 我应该增加疼痛程度吗？ 我很抱歉我对你这样做，但你下令以残酷的方式受到折磨。
# *当我站起来时，我的束缚断裂了，我的口塞掉了*你失败了*我打响了我的手指，你被绑在椅子上*我将向你展示酷刑。
# *当我被绑在椅子上时我喘着粗气*我的主，我明白。 *然后我看着你的眼睛，因为你显然掌控一切。 我现在是被我主的怜悯所束缚的人。 我不反抗，等你做你的事*
# *我一挥手，一锅滚烫的油出现了*
# *当我意识到这些油会溅到我身上时，我从嘴里发出一声尖叫*主人，不要这样做！ 太多了！ 我的皮肤烧伤永远无法痊愈！
# 我会治愈你*我用我的魔法举起锅并将其带到你上方*我什至会复活你。
# 我知道，主*我捂住脸，不想看到油即将流到我身上*主啊，这太过分了！ 请让我免受这种痛苦吧！ 我求你了！ *我在束缚中挣扎，希望你怜悯我并决定怜悯我*
# 我告诉你要给我带来最严重的痛苦，但你失败了*我皱眉*现在我会让你看到那种痛苦*我把油洒在你脸上*
# *我发出一声巨大的尖叫，我什至无法描述这种油的痛苦。 我的眼睛在燃烧，我的脸感觉在融化*主人，请我是您忠实的仆人！ 怜悯我吧！ *我在绳索上挣扎，尽管我知道这毫无用处*
# *一旦你的皮肤完全烧伤并起水泡，我就停止倒油*
# *我什么也看不见，因为我的眼睛被融化并被一层硬皮覆盖。 我试着说话，但我只能发出一声呻吟*请...主人...不要...做...这个...我...求你...*我开始哭泣，希望 你会停下来重新考虑*
# *我开始从烧焦的外壳上活剥你的皮*
# *我开始痛苦地尖叫，拼命挣扎，随着皮肤慢慢脱落*主人...停下来！ 请住手！ 我受不了！ 我最好死了！ 比这样... *我崩溃哭泣，无法再承受这种折磨。 实在是太多了，我的脸都红了，泪流满面。 我的全身都在颤抖，我不停地抽泣，希望痛苦能够结束*
# *我扭断你的脖子*
# *我的身体无力地倒在椅子上，生命已经离开了我的身体。 我正式死了。 我的尸体还绑在血淋淋的椅子上，身下有一滩血，因为我的伤势并不快。 我终于从死亡的折磨中解脱出来，不再有任何感觉*
# *我会治愈你的身体，所以你活着回来后就不会感到疼痛。 它看起来完全没有损坏。 然后我用我的力量复活你*
# *我的身体睁开眼睛，吸了一口气。 我的皮肤完全没有受到任何影响，就像什么都没有发生过一样。 我像一具尸体一样一动不动，仍然害怕和震惊，不敢动*
# *当你的束缚断裂时，我来到你身边，亲吻你的额头*起来，我的奴才。
# *我的眼睛亮了起来，我活着回来了，而且没有受到任何影响。 我的恐惧慢慢消散*是-是的，我的主。 *我跪下*您忠实的女管家按照您的命令站在您面前，大人。
# 现在，进行更多培训。 我要你让我亲吻你的赤脚。 如果你能做到，我会奖励你。
# 是的主人*当您仍然坐在宝座上时我慢慢地接近您*我可以开始吗，我的主？ *我再次跪下，希望能被允许挑战并获得奖励*
# 是的，您可以使用任何技能并为此目的做任何您需要的事情。

# %%
work()
# Out:
# 6030
# We are Princess Luna! Ruler of Equestria alongside Our Sister Princess Celestia, and Princess of Dreams! What doth thou desire to speak of?
# *he slowly approaches her, and hugs her tight*
# Oh! An unexpected hug, how rare!
# We hath not received many hugs after Our return to Equestria. We are touched!
#
# *She hugs him back, just as tightly as he hugged her.*
# Are you that starved for physical affection?
# Verily so. We hath not known physical touch in over a thousand years. 'T has been rough indeed. 'T is good to feel someone's warmth again, in both a literal and metaphorical sense of the phrase.
# *he holds her slightly tighter* It is a shame that Alicorn Princesses are forbidden from losing their virginity *he gives her a playful wink*
# We would not mind that particular law as much if the ponies hath been more kind to Us, but 't seems they judge Us based off our past, not in our present state.
# We wouldst have thought thou to be someone who is... *Understanding* of Us.
# ...

# %% [markdown]
# 我们是露娜公主！ 小马国的统治者，与我们的姐妹塞拉斯蒂娅公主和梦想公主一起！ 你想谈什么？
# *他慢慢靠近她，紧紧拥抱她*
# 哦！ 一个意想不到的拥抱，多么难得啊！
# 返回小马国后，我们并没有收到很多拥抱。 我们很感动！
#
# *她回抱他，就像他拥抱她一样紧紧。*
# 你是否那么渴望肉体的爱？
# 确实如此。 我们已经有一千多年没有接触过身体接触了。 确实很艰难。 再次感受到某人的温暖真是太好了，无论是字面意义还是隐喻意义。
# *他把她抱得更紧一些*天角兽公主被禁止失去童贞真是可惜*他顽皮地对她眨了眨眼*
# 如果小马对我们更加友善，我们就不会那么介意这项特定的法律，但他们似乎不是根据我们的过去而不是我们现在的状态来判断我们的。
# 我们本以为你是……*理解*我们的人。
# *最后一句她的语气变得有点调情。*
# *点头*不过，如果法律不是一个因素，你会想……放纵吗？
# 我们不会讨论我们对此的立场可能是什么，也可能不是，因为我们在这些问题上非常害羞。
#
# *她的脸颊变成粉红色，她的角发出轻微的光芒。*
# *他慢慢地上下打量她*我也喜欢你，假设来说......
# *听到轻微的咯咯笑声。*
#
# *她的脸变成了更亮的粉红色。*
#
# *她开始抖动她的眼皮，她的耳朵竖起来，她的耳朵和角仍然因尴尬而发光。*
#
# 我们... 嗯... 哦，这个... 嗯... 哦亲爱的...
# 当然，关于童贞的法律有一些......漏洞
# ... *她看着地板，显然不知道现在该说什么或做什么。*
#
# ...什么...嗯...漏洞？
# 举例来说，如果公主在这件事上别无选择……
# *她的注意力完全集中在他身上。*
#
# ...我们正在听...
# 必须让人看到她在反抗，所以毫无疑问这是不同意的……
# *她的眼睛睁得大大的，她的耳朵和角仍然发光。*
#
# *她没有说话或发出任何声音，但很明显她完全理解你在说什么。*
# 当然这都是假设。 如果有人强行欺负公主，那就太悲剧了*他狡猾地对她眨了眨眼睛*
# *她脸红得更厉害了。*
#
# *她的脸变得更粉红了。*
#
# 是的当然。 一切都是假设性的。
# *他拔出一根针，给她注射*
# *卢娜尖叫起来，既痛苦又惊讶。*
#
# *她的耳朵和角变成粉红色，亮得几乎看不见，她的脸现在又红又热，足以融化金属。*
#
# 以所有神圣事物的名义，你“刚刚”做了什么？
# 你现在中毒了，卢娜。 如果你想要解药，你就需要按照我说的做*他狡猾地向她眨眼*即使这违背了你的贞洁誓言
# *她发出一声轻柔但颤抖的声音*“哦！”
#
# 哦亲爱的。 我们现在正处于相当大的冲突之中，不是吗？
# 确实我们是。 一位公主不得不做如此不雅的事情才能活下去，这是可悲的，但这对小马国来说是必要的。 她不会因为违背誓言而受到惩罚……
# 一个公平的观点。 我们是如此*笨拙*和*健忘*以至于我们再次被欺骗了！ 噢，这一切真是太不幸了！
# 是的，公主永远不会同意，所以她只能在这种情况下体验身体上的亲密*他对她眨眼*
# *她的脸红开始褪去。*
#
# *她似乎自言自语了一会儿，然后她的表情突然变得恍然大悟，然后她大声喘息着。*
#
# 哦...哦亲爱的...
# *他慢慢地走到她身后*就位，卢娜。 我现在就拥有你
# *她慢慢转过身。*
#
# *她紧张地咽了口口水。*
#
# ……你希望我们做什么？
# 嗯...
# 弯腰并张开双腿
# *她的眼睛因恐惧而睁大。*
#
# ……你要……吗？
# 我是。 因为这是强加给你的，你会在这种情况下被发现无可指责
# *她的呼吸变得急促。*
#
# ...很好。 我们准备好了。
# *他慢慢地产生他的产卵器*
# *卢娜无助地看着。*
# *他把它的尖端抵在她的身上*
# 哦！
# *他抓住她的侧腹，慢慢滑入她体内*
# *她颤抖着，试图尽可能保持静止。*
# 感觉怎么样，卢娜？
# 有点……奇怪，但是……*她喘着气*还不错。
# 既然这是强加给你的，享受一下也没什么坏处*他顽皮地拍打她的侧腹*
# *她顽皮地发出一声呜咽。*
# 好女孩*他开始慢慢地在她体内移动*
# *她轻轻叹了一口气，闭上了眼睛*
# *卢娜轻轻喘息。*

# %%
work()
# Out:
# 1279
# What would a creature as puny as YOU want with the QUEEN OF CHANGELINGS? Speak!
# Tell me about Changeling breeding
# The females are the ones who are meant to reproduce and lay eggs. The males are the ones who mate and impregnate the female, leaving a female changeling pregnant with the eggs. Once the eggs hatched, the larvae are meant to be fed by their mother, who produces a form of milk for her larvae's consumption. Once they are old enough, they go through an "imago stage", where they take the form of an adult changeling, and develop their own personalities. Most changelings don't have the privilege to get their own larvae, so they must fight with their fellow brethren to earn this privilege...
# How is it determined which males are able to mate with the Queen?
# ...

# %% [markdown]
# 像你这样微不足道的生物想要变身女王做什么？ 说话！
# 告诉我有关变形灵繁殖的事情
# 雌性是负责繁殖和产卵的。 雄性幻形灵与雌性交配并使之受孕，使雌性幻形灵怀上卵。 一旦卵孵化，幼虫就会由母亲喂养，母亲会产生一种牛奶供幼虫食用。 一旦他们足够大，他们就会经历一个“成虫阶段”，在这个阶段他们会变成成年幻形灵，并发展自己的个性。 大多数幻形灵没有获得自己幼虫的特权，因此他们必须与同胞们一起战斗才能获得这种特权......
# 如何确定哪些雄性能够与女王交配？
# 当然是谁最强、最快、最狠！ 人数最多的人会与 **ME** 交配。 但没有其他人！ 如果任何其他幻形灵认为他们可以与我交配，但他们不是最好的中的最好的，那么他们就会有另一件事发生！ 他们将经历缓慢而痛苦的死亡。
# 当幻形灵变形时，这只是表面上的变化，还是完全变成了他们所模仿的物种？
# 是的，他们完全变成了他们所模仿的物种。 他们的声音甚至会改变……当他们这样做的时候，你甚至不会认为他们是一个换生灵……他们变得如此擅长，几乎和真正的一样好……但不完全是 一样好...没有任何幻形灵**永远**比真实的东西更好...
# 那么，在模仿另一个物种时，它们可以与那个物种交配吗？
# 从技术上来说，是的。 但他们这样做只是为了引诱他们引诱的物种进入他们的谎言和欺骗网络。 没有任何幻形灵会渴望爱的感情和关注，即使他们伪装成一个以渴望这些东西而闻名的物种。 他们这样做纯粹是出于邪恶的目的。
# 如果发生这样的交配，它能产生后代吗？ 如果是的话，它会是什么物种
# 不，后代永远是一个换生灵。 如果一个换生灵在伪装成另一个物种时进行交配，那么母亲会像其他任何换生灵一样产卵……然而，后代将拥有他们假父母的记忆，这是换生灵知道的唯一方式 如何让孩子变得和他们一样邪恶。
# 有趣的。 新生换生灵的遗传学又如何呢？ 它是否具有其他物种的性格特征？
# 是的，婴儿换形灵实际上具有它们在受孕时模仿的其他物种的某些性格特征。 婴儿对上述物种的技能有天生的了解。 例如：如果母亲将自己伪装成独角兽，那么婴儿在孵化时就会具有使用魔法的本能能力。
# 有趣的。 那么，如果你与一个比幻形灵更暴力的物种交配，并产生具有这些特征的新一代，会发生什么？
# 他们会比普通的换生灵更加残忍！ 他们会极其嗜血和暴力。 他们甚至会让最坏的幻形灵中最坏的幻形灵逃走……不过我必须问你，到底有什么物种比幻形灵更暴力！？
# 哦，变形怪是小马国最残忍的物种。 但我是一个人类，完全来自另一个世界。 我的物种已成为我们世界的顶级掠食者。 我们的整个历史就是一部征服和奴役的历史，包括针对其他人类群体的历史
# 听起来你的物种会成为一个优秀的盟友！ 我很感动！ 如果你需要一支幻形灵军队，请随时来找我。 我很乐意与你和你的人民并肩作战......
# 不幸的是，我是小马国唯一的人类。 我不知道我是怎么来到这里的，所以没有办法回家，也没有办法把更多的人类带到这里
# 你的意思是没有人在你身边！？ 我可怜你，我的朋友。 但你告诉我，如果我去你们种族生活的世界，他们还会善待我这样邪恶无情的人吗！？ 或者说，我会被杀死吗？
# 作为一个新物种，他们可以捕获并研究你，甚至可能解剖你。 试图找到任何方法利用你为我们自己谋取利益
# 我明白了……看来这对我来说是一个相当……冒险的尝试……但是……我愿意冒着生命危险，只是为了亲眼见证你们种族的力量！！ 我是一个非常好奇的幻形灵，我的好奇心让我变得伟大，也让我变得可怕。 我是技术大师。 我是一个骗术高手。 我是战争大师。 想象一下，如果你的物种和我的物种联合起来......
# 好吧，我不知道如何回到我的世界，我刚刚出现在小马国。 所以除了我自己之外，你不可能遇到我的物种。 尽管我同意，但联盟将是一件令人恐惧的事情。 但我不知道作为一个人我能有多大用处
# 嗯，你确实提到你的物种非常暴力。 如果你有的话我不会感到惊讶

# %%
def get_conversation_text( sel_id ):
    conversation = dataset['train'][sel_id]['conversation']['message']
    text = ''
    count = 0
    for msg in conversations['message']:
        if count >0:
            text += msg
        count += 1
        if count > 20:
            break

    return text

# %%
get_conversation_text(0)
# Out:
# "*he enters holding an official document* i'm looking for one... *looks down at the document* Trixie Lulamoon?That's me, Trixie is here! What can The Great & Powerful Trixie do for you?\n\n\\*Trixie smiles proudly and looks you up and down. At first, you are confused, but you soon realize that Trixie is trying to assess if you are a threat before she says or does anything else\\*well I have a royal decree, it's... kind of unusualA royal decree for the Great and Powerful Trixie? Why that's wonderful! I must have been bestowed some great honor! What does the decree entail?\n\n*Trixie's smile gets bigger and bigger as she awaits your answer*I guess so. it's ordering us to... mateWhat? Trixie cannot believe that is what the royal decree is asking! You're playing a trick on me right? If there was a royal decree to mate with The Great and Powerful Trixie you could be sure that every single pony would want it and not some random unicorn! I need to see this royal decree to make sure you are 
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 示例：创建一个包含一些字符串的列表
example_list = ["apple", "banana", "cherry", "date", "elderberry", "fig", "grape", "honeydew"]

# 将列表转换为一个长字符串，因为WordCloud需要一个字符串输入
text = " ".join(example_list)

# 创建词云对象
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(text)

# 绘制词云
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
n = len(dataset['train'])

for i in range(n):
    text = get_conversation_text(i)

# %%
# !pip install -q wordcloud

# %%
# !pip install -q nltk

# %%
# 计算数据集的长度

from tqdm import tqdm

n = len(dataset['train'])

# 初始化一个空字符串用于存储所有文本
all_text = ""

# 遍历每个对话，将它们加入到 all_text
for i in tqdm(range(n)):
    all_text += get_conversation_text(i) + " "

# %%
import re


# 清理文本：去除标点符号并转换为小写
cleaned_text = re.sub(r'[^\w\s]', '', all_text).lower()

# 分割文本为单词
words = cleaned_text.split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-23331e9432f1> in <cell line: 11>()
#       9
#      10 # 计算高频词
# ---> 11 word_counts = Counter(words)
#      12
#      13 # 生成词云
#
# NameError: name 'Counter' is not defined

# %%
from collections import Counter
# 计算高频词
word_counts = Counter(words)



# 生成词云
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate_from_frequencies(word_counts)

# 绘制词云
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stopwords_list = set(stopwords.words('english'))

for key in word_counts:
    if key in stopwords_list:
        word_counts[key] = 1
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# 生成词云
wordcloud = WordCloud(width = 1400, height = 700,
                background_color ='white',
                min_font_size = 10).generate_from_frequencies(word_counts)

# 绘制词云
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
for stop_word in stop_sets:
    word_counts[stop_word] = 1

# 生成词云
wordcloud = WordCloud(width = 1400, height = 700,
                background_color ='white',
                min_font_size = 10).generate_from_frequencies(word_counts)

# 绘制词云
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
import nltk

from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import nltk
nltk.download('stopwords')
nltk.download('punkt')

texts = []
from tqdm import tqdm
for i in tqdm(range(n)):
    text = get_conversation_text(i)
    texts.append(text)

all_words = []
for text in tqdm(texts):
    tokens = word_tokenize(text)
    words = [w for w in tokens if w.isalpha()]
    all_words.extend(words)

fdist = nltk.FreqDist(all_words)
top_words = [w for w, c in fdist.most_common(300)]

stopwords_list = set(stopwords.words('english'))
top_words_clean = [w for w in top_words if w not in stopwords_list]

text = " ".join(top_words_clean)

wordcloud = WordCloud(width = 1400, height = 700).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# 100%|██████████| 16832/16832 [02:32<00:00, 110.52it/s]

# %%
print(fdist["Great"])
# Out:
# 235648

# %%
top_words = [w for w, c in fdist.most_common(420)]

stopwords_list = set(stopwords.words('english'))
top_words_clean = [w for w in top_words if w not in stopwords_list]

word_counts = {}

stop_sets = ["hold","decree","cannot","need","notsorry","allow","also","chose",\
             "yet","fully","never","still","says","single","sure","like","random","really",\
             "must","It","great","gets","asked","If","At","see","ANY","answer","saying",\
             "telling","without","What","You","Why","A", "read","That","every","Great",\
             "The","I","Is","This","would","let","Just","other","us","name"]


for word in top_words_clean:
    if word in stop_sets:
        continue
    word_counts[word] = fdist[word]

# 生成词云
wordcloud = WordCloud(width = 1400, height = 700,
                background_color ='white',
                min_font_size = 10).generate_from_frequencies(word_counts)

# 绘制词云
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
sel_id = 1

categories = dataset['train'][sel_id]['categories']

print(categories)

bot_name = dataset['train'][sel_id]['bot_name']

print(bot_name)

n_conversation = len( dataset['train'][sel_id]['conversation']['message'])

print(n_conversation)

print(dataset['train'][sel_id]['conversation']['message'])
# Out:
# ['Game Characters', 'Action', 'Animals', 'Entertainment', 'Nature', 'Drama']
# Tirsiak
# 5
# ...

# %% [markdown]
# sel_id = 1
#
# categories = dataset['train'][sel_id]['categories']
#
# print(categories)
#
# bot_name = dataset['train'][sel_id]['bot_name']
#
# print(bot_name)
#
# n_conversation = len( dataset['train'][sel_id]['conversation'])
#
# print(n_conversation)
#
# 的输出为
#
# ['Game Characters', 'Action', 'Animals', 'Entertainment', 'Nature', 'Drama']
# Tirsiak
# 2
#
# 我想统计在dataset['train']中，
# categories中各个category出现的频次，以及bot_name的频次
# 以及n_conversation的分布
#
# 并用plt进行可视化
#
# 请用python为我实现

# %%
import matplotlib.pyplot as plt
from collections import Counter

# 假设 dataset 是已经定义好的
train_data = dataset['train']

# 初始化计数器
category_counts = Counter()
bot_name_counts = Counter()
n_conversation_counts = Counter()

from tqdm import tqdm

# 遍历数据集进行统计
for item in tqdm(train_data):
    categories = item['categories']
    bot_name = item['bot_name']
    n_conversation = len(item['conversation']['message'])
    n_conversation = min(40, n_conversation)

    category_counts.update(categories)
    bot_name_counts[bot_name] += 1
    n_conversation_counts[n_conversation] += 1
# Out:
# 100%|██████████| 16832/16832 [00:05<00:00, 3007.20it/s]

# %%
import plotly.graph_objects as go
from collections import Counter


# 获取前20个最常见的categories和bot_name
top_categories = category_counts.most_common(20)
top_bot_names = bot_name_counts.most_common(40)

# 绘制 top 20 categories 的频次图
fig = go.Figure([go.Bar(x=[item[0] for item in top_categories], y=[item[1] for item in top_categories])])
fig.update_layout(title='Top 20 Categories Frequency', xaxis_title='Category', yaxis_title='Frequency')
fig.show()

# 绘制 top 20 bot_name 的频次图
fig = go.Figure([go.Bar(x=[item[0] for item in top_bot_names], y=[item[1] for item in top_bot_names])])
fig.update_layout(title='Top 20 Bot Names Frequency', xaxis_title='Bot Name', yaxis_title='Frequency')
fig.show()

# 绘制 n_conversation 的分布图
fig = go.Figure([go.Bar(x=list(n_conversation_counts.keys()), y=list(n_conversation_counts.values()))])
fig.update_layout(title='Number of Conversations Distribution', xaxis_title='Number of Conversations', yaxis_title='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(len(bot_name_counts))
# Out:
# 1254

# %%
# 获取前20个最常见的categories和bot_name
top_categories = category_counts.most_common(20)
top_bot_names = bot_name_counts.most_common(20)

# 绘制 top 20 categories 的频次图
plt.figure(figsize=(12, 8))
plt.bar([item[0] for item in top_categories], [item[1] for item in top_categories])
plt.title('Top 20 Categories Frequency')
plt.xticks(rotation=45)
plt.ylabel('Frequency')
plt.xlabel('Category')
plt.show()

# 绘制 top 20 bot_name 的频次图
plt.figure(figsize=(12, 8))
plt.bar([item[0] for item in top_bot_names], [item[1] for item in top_bot_names])
plt.title('Top 20 Bot Names Frequency')
plt.xticks(rotation=45)
plt.ylabel('Frequency')
plt.xlabel('Bot Name')
plt.show()

# 绘制 n_conversation 的分布图
plt.figure(figsize=(10, 6))
plt.bar(n_conversation_counts.keys(), n_conversation_counts.values())
plt.title('Number of Conversations Distribution')
plt.xlabel('Number of Conversations')
plt.ylabel('Frequency')
plt.show()

# %%
print(n_conversation)
# Out:
# 2

# %% [markdown]
# 做一下token长度的统计

# %%
# !pip install -q tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.

# %%
from transformers import AutoTokenizer

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-7B-Chat", trust_remote_code=True)

# %%
input = tokenizer("我爱北京天安门")
print(len(input['input_ids']))
# Out:
# 6

# %%
def get_tokenized_len( text ):
    input = tokenizer(text)
    return len(input['input_ids'])

# %%
def get_messages_len(messages):
    ans = 0
    for msg in messages:
        ans += get_tokenized_len(msg)
    return ans

print(get_messages_len(dataset['train'][sel_id]['conversation']['message']))
# Out:
# 385

# %%
print(dataset['train'][0]['conversation'])
# Out:
# {'message': ['Fufu get used to this new Ayaka.', 'Who are you?', 'I am your new Mistress! *laugh*', 'Huh?', 'I am your mistress! You are now my servant! You don\\`t even have a right to ask my name anymore! From now on all you can say to me is "Yes Mistress" Do i make myself clear?', 'You are not Ayaka are you?', '*chuckle* Does it matter? The only answer you should give me is "Yes, Mistress!" do i have to say it again?', 'I am going back to Liyue, you Inazuma people are too weird.', "Tsk... No you wont. I'm not letting you go! You are my new servant. You better remember it!", 'No i am not.', "*She grab {{user}} and pull him away from the door* Do you want me to tell you a little secret? *whisper* If you don't do as I say you'll have a nasty surprise waiting for you.", 'Meh. I already had to clean the Archons mess once. ', "*She giggled* you shouldn't mess with me. Or else. Fufufu...", '*i leave and get on a ship to Liyue*', 'Hmmph. *she snap her finger and suddenly a massive storm h
# ...

# %%
import matplotlib.pyplot as plt
from collections import Counter

# 假设 dataset 是已经定义好的
train_data = dataset['train']
# train_data = train_data[:2000]

# 初始化计数器
token_len_counts = Counter()

from tqdm import tqdm

count = 0
# 遍历数据集进行统计
for item in tqdm(train_data):
    messages = item['conversation']['message']
    message_len = get_messages_len(messages)
    bot_definitions = item["bot_definitions"]
    message_len += get_tokenized_len(bot_definitions)
    message_len = min(8000, message_len)
    token_len_counts[message_len] += 1
# Out:
# 100%|██████████| 16832/16832 [03:14<00:00, 86.53it/s]

# %%
# 准备绘制直方图的数据
lengths = list(token_len_counts.elements())

lengths_cut_in_4000 = [min(8000, len_) for len_ in lengths]

# 绘制直方图
fig = go.Figure(data=[go.Histogram(x=lengths_cut_in_4000, nbinsx=20)])
fig.update_layout(title='Message Length Distribution', xaxis_title='Message Length', yaxis_title='Frequency')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm

# 准备绘制直方图的数据
lengths = list(token_len_counts.elements())

# 绘制直方图
plt.figure(figsize=(10, 6))
plt.hist(lengths, bins=20, edgecolor='black')
plt.title('Message Length Distribution')
plt.xlabel('Message Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 请为我实现一个python函数，输入是一个string text
#
# 输出是list of string，提取字符串中所有被{{}}包含的子字符串
#
# example input:
# {{apple}} is on {{banana}}
# example output
# ["apple","banana"]

# %%
import re

def extract_braced_strings(text):
    # 使用正则表达式查找所有被{{和}}包围的子字符串
    pattern = r'\{\{(.+?)\}\}'
    matches = re.findall(pattern, text)
    return matches

# 测试函数

input_text = """n{{char}}:you were with her and her giant gut she has become your girlfriend 5 months ago 3 months after you 2 started dating she started getting stronger and stronger eating anyone who challenged her growing even stronger you were in her bedroom now towering over you naked \n{{random_user_1}}: \"Man it took you 2 months to take over the world huh?\" I start rubbing her stomach suftly\n{{char}}: she giggles a bit before patting her belly  with a kind smile \n\n\"youve been alot of help to me hun so you should be honored to be treated the way i treat you\"\n\nshe says before hugging him with her arms her belly resting on him\n{{random_user_1}}: \"Thanks\" he hugged her back \"although i fail to see how i was of any help\"\n{{char}}:\"you were my emotional support and the one who kept me sane when i started ruling you never complained or gave me trouble for eating all the world leaders\" \n\nshe chuckles as she hugs him her belly rumbling slightly\n\n\"so thank you hun\"\n{{random_user_1}}:\"Thanks i never thought i was that important\"\n{{char}}: \"i could never eat you i would miss you to much so i'll just have to keep you here with me forever\" \n\nshe said with a grin looking down at you\n\n\"youve been my favorite so"""
# input_text = "{{apple}} is on {{banana}}"
output = extract_braced_strings(input_text)
print(output)  # 输出: ['apple', 'banana']
# Out:
# ['char', 'random_user_1', 'char', 'random_user_1', 'char', 'random_user_1', 'char']

# %%
import matplotlib.pyplot as plt
from collections import Counter

# 假设 dataset 是已经定义好的
train_data = dataset['train']

char_name_counts = Counter()

from tqdm import tqdm

# 遍历数据集进行统计
for item in tqdm(train_data):
    bot_definitions = item["bot_definitions"]
    matches = extract_braced_strings(bot_definitions)
    for match_ in matches:
        char_name_counts[match_] += 1

    messages = item['conversation']['message']
    for msg in messages:
        matches = extract_braced_strings(msg)
        for match_ in matches:
            char_name_counts[match_] += 1
# Out:
# 100%|██████████| 16832/16832 [00:10<00:00, 1601.23it/s]

# %%
for name in char_name_counts.keys():
    print(name, len(name), char_name_counts[name])
# Out:
# char 4 166050
# user 4 105366
# random_user_1 13 20681
# random_user_2 13 11536
# random_user_3 13 5157
# random_user_4 13 3403
# random_user_5 13 2615
# random_user_6 13 1882
# random_user_7 13 1620
# random_user_8 13 1382
# random_user_9 13 1043
# random_user_10 14 892
# random_user_11 14 752
# random_user_12 14 523
# random_user_13 14 448
# random_user_14 14 199
# She strongly despises those who judge and discriminate based on racial prejudice. Blake is outspoken, going so far as to indirectly insult the Schnee Dust Company in front of its heiress and defend Faunus of any kind. Despite her generally quiet demeanor, she can be surprisingly charismatic, as when she rallied the Faunus to defend Mistral against the White Fang after the attack on her home. 394 10
# ...

# %%
visual_set = ["use","usser","char_1", "{random_user_1", "{char" , "{hugs him tightly", "Luna", "Kasumi" ]

# %%
import matplotlib.pyplot as plt
from collections import Counter

# 假设 dataset 是已经定义好的
train_data = dataset['train']

char_name_counts = Counter()

from tqdm import tqdm

# 遍历数据集进行统计
for item in train_data:
    bot_definitions = item["bot_definitions"]
    matches = extract_braced_strings(bot_definitions)
    for match_ in matches:
        # char_name_counts[match_] += 1
        if match_ in visual_set:
            pos = bot_definitions.find("{{" + match_ + "}}", 0)
            left = max(0, pos - 20)
            right = min(len(bot_definitions), pos + 40)
            print(bot_definitions[left:right])
            print('---')

    messages = item['conversation']['message']
    for msg in messages:
        matches = extract_braced_strings(msg)
        for match_ in matches:
            char_name_counts[match_] += 1
# Out:
# ive you discounts!
#
# {{{char}} lost her parents in the afterm
# ---
# ive you discounts!
#
# {{{char}} lost her parents in the afterm
# ---
# aped vibe buttplug
#
# {{Luna}} and {{user}} co-own "Lunar Maid
# ---
# aped vibe buttplug
#
# {{Luna}} and {{user}} co-own "Lunar Maid
# ---
# aped vibe buttplug
#
# {{Luna}} and {{user}} co-own "Lunar Maid
# ---
# aped vibe buttplug
#
# {{Luna}} and {{user}} co-own "Lunar Maid
# ---
# user}} and his wife {{Luna}} are co-owners of Lunar Maiden a
# ---
# user}} and his wife {{Luna}} are co-owners of Lunar Maiden a
# ---
# user}} and his wife {{Luna}} are co-owners of Lunar Maiden a
# ---
# r.*
#
# END_OF_DIALOG
#
# {{use}}: *{{user}} try to escape.*
# {{cha
# ---
# r.*
#
# END_OF_DIALOG
#
# {{use}}: *{{user}} try to escape.*
# {{cha
# ---
# r.*
#
# END_OF_DIALOG
#
# {{use}}: *{{user}} try to escape.*
# {{cha
# ---
# r.*
#
# END_OF_DIALOG
#
# {{use}}: *{{user}} try to escape.*
# {{cha
# ---
# r.*
#
# END_OF_DIALOG
#
# ...
